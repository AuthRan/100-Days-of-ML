# %%
from ydata_profiling import ProfileReport
import pandas as pd

titanic = pd.read_csv('data/train.csv')

# Create the report
profile = ProfileReport(titanic, title="Titanic Dataset Report")

# Display in Jupyter
# profile.to_widgets()

# Or save to HTML
profile.to_file("titanic_report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 43.71it/s]
